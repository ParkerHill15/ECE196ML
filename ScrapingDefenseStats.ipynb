# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import requests
import time

# %%
# Starting with the 2002 season as prior to then there were 31 teams in the league
# With the Texans added in 2002
requests.get('https://www.pro-football-reference.com/years/2002/opp.htm')
url_text = requests.get('https://www.pro-football-reference.com/years/2002/opp.htm').text
soup = BeautifulSoup(url_text)
soup.prettify()
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-root="/home/pfr/build" data-version="klecko-" itemscope="" itemtype="https://schema.org/WebSite" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport"/>
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/202010132" rel="dns-prefetch"/>
# <title>2002 NFL Opposition &amp; Defensive Statistics | Pro-Football-Reference.com</title>
# <meta content="2002 NFL Opposition &amp; Defensive Statistics" name="Description"/>
# <link href="https://www.pro-football-reference.com/years/2002/opp.htm" rel="canonical"/>
# <!-- include:start ="/inc/klecko_header_pfr.html_f" -->
# <!-- no:cookie fast load the css.           -->
# ...

# %%
teams = soup.find_all('td')[0].text #every 27 td is a name of a team
print(teams)
# Out:
# Tampa Bay Buccaneers

# %%
teams = []
iterator = 0
for x in range(0,32):
    teams.append(soup.find_all('td')[iterator].text)
    iterator += 27
print(teams)
# Out:
# ['Tampa Bay Buccaneers', 'Philadelphia Eagles', 'New York Giants', 'Miami Dolphins', 'Carolina Panthers', 'Oakland Raiders', 'Indianapolis Colts', 'Atlanta Falcons', 'Jacksonville Jaguars', 'Cleveland Browns', 'Tennessee Titans', 'Green Bay Packers', 'Dallas Cowboys', 'New York Jets', 'Denver Broncos', 'Pittsburgh Steelers', 'New England Patriots', 'San Francisco 49ers', 'Baltimore Ravens', 'Houston Texans', 'Washington Redskins', 'San Diego Chargers', 'Seattle Seahawks', 'St. Louis Rams', 'Chicago Bears', 'New Orleans Saints', 'Buffalo Bills', 'Kansas City Chiefs', 'Arizona Cardinals', 'Minnesota Vikings', 'Detroit Lions', 'Cincinnati Bengals']

# %%
dataframe = pd.DataFrame(teams,index = range(1,33),columns = ['Teams'])

# %%
dataframe
# Out:
#                    Teams
# 1   Tampa Bay Buccaneers
# 2    Philadelphia Eagles
# 3        New York Giants
# 4         Miami Dolphins
# 5      Carolina Panthers
# 6        Oakland Raiders
# 7     Indianapolis Colts
# 8        Atlanta Falcons
# 9   Jacksonville Jaguars
# 10      Cleveland Browns
# 11      Tennessee Titans
# 12     Green Bay Packers
# 13        Dallas Cowboys
# 14         New York Jets
# 15        Denver Broncos
# 16   Pittsburgh Steelers
# 17  New England Patriots
# 18   San Francisco 49ers
# 19      Baltimore Ravens
# 20        Houston Texans
# 21   Washington Redskins
# 22    San Diego Chargers
# 23      Seattle Seahawks
# 24        St. Louis Rams
# 25         Chicago Bears
# 26    New Orleans Saints
# 27         Buffalo Bills
# 28    Kansas City Chiefs
# 29     Arizona Cardinals
# 30     Minnesota Vikings
# 31         Detroit Lions
# 32    Cincinnati Bengals

# %%
data.to_csv('2002Defense.csv')
# Out:
#    Blah
# 0   Boi
# 1   You
# 2  Suck

# %%
#Finalized webscraping code for defenses
data = pd.DataFrame()
for i in range(2002,2020):
    url_text = requests.get(f'https://www.pro-football-reference.com/years/{i}/opp.htm').text
    soup = BeautifulSoup(url_text)
    teams = []
    iterator = 0
    for x in range(0,32):
        teams.append(soup.find_all('td')[iterator].text)
        iterator += 27
    data[f'{i}'] = teams
data.to_csv('Defense.csv')

# %%
newdata = pd.read_csv(r'C:\Users\Parker Hill\Desktop\ECE 196\NFL Running Back\Defense.csv')

# %%
frame = pd.DataFrame(newdata)
year = frame['2003']
singular = frame['2003'][0]
typeof = type(frame['2003'][0])
print(year)
print(singular)
print(typeof)
# Out:
# 0     New England Patriots
# 1           Dallas Cowboys
# 2           Miami Dolphins
# 3     Tampa Bay Buccaneers
# 4            Buffalo Bills
# 5         Baltimore Ravens
# 6      Philadelphia Eagles
# 7            New York Jets
# 8           Denver Broncos
# 9        Carolina Panthers
# 10       Green Bay Packers
# 11        Cleveland Browns
# 12        Tennessee Titans
# 13      New Orleans Saints
# 14        Seattle Seahawks
# 15     Pittsburgh Steelers
# 16          St. Louis Rams
# 17    Jacksonville Jaguars
# 18      Kansas City Chiefs
# 19      Indianapolis Colts
# 20     San Francisco 49ers
# 21           Chicago Bears
# 22       Minnesota Vikings
# 23     Washington Redskins
# 24         Oakland Raiders
# 25           Detroit Lions
# 26          Houston Texans
# 27      Cincinnati Bengals
# 28         New York Giants
# 29         Atlanta Falcons
# 30      San Diego Chargers
# 31       Arizona Cardinals
# Name: 2003, dtype: object
# New England Patriots
# <class 'str'>
